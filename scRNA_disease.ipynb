# %% [markdown]
# Description:
# We integrated and analyzed the single-cell transcriptomes of 48 human pancreatic islets coming from 17 Healthy, 14 Pre-Diabetic and 17 Type 2 Diabetic cadaveric donors of matched sex, age, and ancestry. Our dataset consists of 245,878 high-quality cells, clustered into 14 cell types. We summarize the findings of the integrated cell type transcriptomes, as well as those of the re-integrated Alpha, Beta and Delta cell types.
#
# Reference:
# Single-cell decoding of human islet cell type-specific alterations in type 2 diabetes reveals converging genetic- and state-driven β-cell gene expression defects
# Khushdeep Bandesh, Efthymios Motakis, Siddhi Nargund, Romy Kursawe, Vijay Selvam, Redwan M Bhuiyan, Giray Naim Eryilmaz, Sai Nivedita Krishnan, Cassandra N. Spracklen, Duygu Ucar, Michael L. Stitzel
# bioRxiv 2025.01.17.633590; doi: https://doi.org/10.1101/2025.01.17.633590
#
# Data: https://datasets.cellxgene.cziscience.com/d45ff50f-90e1-4983-9388-c5b2ca1f2866.h5ad

# %%
# !pip install scanpy
# !pip install igraph
# !pip install leidenalg
# !pip install anndata
# !pip install pandas
# Out:
# Requirement already satisfied: scanpy in /opt/anaconda3/lib/python3.12/site-packages (1.10.1)
# Requirement already satisfied: anndata>=0.8 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.12.2)
# Requirement already satisfied: h5py>=3.1 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (3.11.0)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (1.4.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (1.4.1)
# Requirement already satisfied: matplotlib>=3.6 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (3.7.5)
# Requirement already satisfied: natsort in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (3.3)
# Requirement already satisfied: numba>=0.56 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.5.6)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.5.13)
# Requirement already satisfied: scikit-learn>=0.24 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (1.7.1)
# Requirement already satisfied: scipy>=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (1.13.1)
# Requirement already satisfied: seaborn>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (1.0.1)
# Requirement already satisfied: statsmodels>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.14.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (4.66.5)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from scanpy) (0.5.9.post2)
# Requirement already satisfied: array-api-compat>=1.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from anndata>=0.8->scanpy) (1.12.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /opt/anaconda3/lib/python3.12/site-packages (from anndata>=0.8->scanpy) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.56->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.5->scanpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.5->scanpy) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.24->scanpy) (3.5.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy->scanpy) (1.16.0)
# Requirement already satisfied: stdlib_list in /opt/anaconda3/lib/python3.12/site-packages (from session-info->scanpy) (0.11.1)
# Requirement already satisfied: donfig>=0.8 in /opt/anaconda3/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (0.16.2)
# Requirement already satisfied: typing-extensions>=4.9 in /opt/anaconda3/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (4.11.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.1)
# Requirement already satisfied: crc32c>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (2.7.1)
# Requirement already satisfied: igraph in /opt/anaconda3/lib/python3.12/site-packages (0.11.9)
# Requirement already satisfied: texttable>=1.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from igraph) (1.7.0)
# Requirement already satisfied: leidenalg in /opt/anaconda3/lib/python3.12/site-packages (0.10.2)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from leidenalg) (0.11.9)
# Requirement already satisfied: texttable>=1.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.7.0)
# Requirement already satisfied: anndata in /opt/anaconda3/lib/python3.12/site-packages (0.12.2)
# Requirement already satisfied: array-api-compat>=1.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (1.12.0)
# Requirement already satisfied: h5py>=3.8 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (3.11.0)
# Requirement already satisfied: legacy-api-wrap in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (1.4.1)
# Requirement already satisfied: natsort in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (8.4.0)
# Requirement already satisfied: numpy>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (1.26.4)
# Requirement already satisfied: packaging>=24.2 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (25.0)
# Requirement already satisfied: pandas!=2.1.2,>=2.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (2.2.2)
# Requirement already satisfied: scipy>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (1.13.1)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /opt/anaconda3/lib/python3.12/site-packages (from anndata) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.2,>=2.1.0->anndata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.2,>=2.1.0->anndata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.2,>=2.1.0->anndata) (2023.3)
# Requirement already satisfied: donfig>=0.8 in /opt/anaconda3/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata) (0.16.2)
# Requirement already satisfied: typing-extensions>=4.9 in /opt/anaconda3/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (4.11.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata) (6.0.1)
# Requirement already satisfied: crc32c>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata) (2.7.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.2,>=2.1.0->anndata) (1.16.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests

url = 'https://datasets.cellxgene.cziscience.com/d45ff50f-90e1-4983-9388-c5b2ca1f2866.h5ad'
response = requests.get(url)

# %%
#Save the file locally
with open('d45ff50f-90e1-4983-9388-c5b2ca1f2866.h5ad', 'wb') as file:
    file.write(response.content)

# %%
sc_data = sc.read_h5ad("d45ff50f-90e1-4983-9388-c5b2ca1f2866.h5ad")

# %%
output_h5ad = sc_data.copy()

sc.pp.normalize_total(output_h5ad)

sc.pp.log1p(output_h5ad)

# %%
#print(output_h5ad.var.columns)
# Out:
# Index(['vst.mean', 'vst.variance', 'vst.variance.expected',
#        'vst.variance.standardized', 'vst.variable', 'feature_is_filtered',
#        'feature_name', 'feature_reference', 'feature_biotype',
#        'feature_length', 'feature_type'],
#       dtype='object')

# %%
#print(output_h5ad.var['feature_name'])
# Out:
# ENSG00000241860    ENSG00000241860
# ENSG00000286448    ENSG00000286448
# ENSG00000237491          LINC01409
# ENSG00000177757             FAM87B
# ENSG00000228794          LINC01128
#                         ...
# ENSG00000261442    ENSG00000261442
# ENSG00000262815    ENSG00000262815
# ENSG00000267480          LINC02979
# ENSG00000236352    ENSG00000236352
# ENSG00000228459          LINC01546
# Name: feature_name, Length: 26936, dtype: category
# Categories (26896, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
# Find genes containing 'KIF21A'
#matches = [gene for gene in output_h5ad.var.feature_name if 'KIF21A' in gene]
#print(matches)
# Out:
# ['KIF21A']

# %%
normal_h5ad = output_h5ad[output_h5ad.obs.disease == 'normal', :]
T2D_h5ad = output_h5ad[output_h5ad.obs.disease == 'type 2 diabetes mellitus', :]

# %%
gene_name = 'KIF21A'

normal_expr = normal_h5ad[:, normal_h5ad.var.feature_name == gene_name].X.toarray().flatten()
T2D_expr = T2D_h5ad[:, T2D_h5ad.var.feature_name == gene_name].X.toarray().flatten()

normal_expr = list(filter(lambda x: x != 0, normal_expr))
T2D_expr = list(filter(lambda x: x != 0, T2D_expr))

# %%
max_length = max(len(normal_expr), len(T2D_expr))
df = pd.DataFrame({
    'normal': normal_expr + [None] * (max_length - len(normal_expr)),
    'type 2 diabetes mellitus': T2D_expr + [None] * (max_length - len(T2D_expr)),
})
df.to_csv('sc_human_KIF21A_expr_disease.csv', index=False)

# %%
df = pd.DataFrame({
    'Kif21a': np.concatenate([normal_expr, T2D_expr]),
    'Group': ['normal'] * len(normal_expr) + ['type 2 diabetes mellitus'] * len(T2D_expr)
})

# Create violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(x='Group', y='Kif21a', data=df)
plt.title(f'KIF21A Expression in human normal vs type 2 diabetes mellitus')
plt.ylabel('KIF21A Gene Expression')
plt.show()
